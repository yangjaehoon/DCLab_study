# %% [markdown]
# # 2.3 퍼셉트론 구현하기

# %% [markdown]
# 2.3.1 간단한 구현

# %%
def AND(x1, x2):
  w1, w2, theta = 0.5, 0.5, 0.7
  tmp = x1*w1 + x2*w2
  if tmp <= theta:
    return 0
  elif tmp > theta:
    return 1

# %%
print(AND(0, 0))
print(AND(1, 0))
print(AND(0, 1))
print(AND(1, 1))
# Out:
# 0
# 0
# 0
# 1

# %% [markdown]
# 2.3.2 가중치와 편향 도입

# %%
import numpy as np
x = np.array([0, 1])
w = np.array([0.5, 0.5])
b = -0.7

# %%
w*x
# Out:
# array([0. , 0.5])

# %%
np.sum(w*x)
# Out:
# np.float64(0.5)

# %%
np.sum(w*x) + b
# Out:
# np.float64(-0.19999999999999996)

# %% [markdown]
# 2.3.3 가중치와 편향 구현하기

# %%
def AND(x1, x2):
  x = np.array([x1, x2])
  w = np.array([0.5, 0.5])
  b = -0.7
  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else:
    return 1

# %%
def NAND(x1, x2):
  x = np.array([x1, x2])
  w = np.array([-0.5, -0.5])
  b = 0.7
  tmp = np.sum(w*x) +b
  if tmp <= 0:
    return 0
  else:
    return 1

# %%
def OR(x1, x2):
  x = np.array([x1, x2])
  w = np.array([0.5, 0.5])
  b = -0.2
  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else:
    return 1

# %% [markdown]
# 2.5.2 XOR 게이트 구현하기

# %%
def XOR(x1, x2):
  s1 = NAND(x1, x2)
  s2 = OR(x1, x2)
  y = AND(s1, s2)
  return y

# %%
print(XOR(0,0))
print(XOR(1,0))
print(XOR(0,1))
print(XOR(1,1))
# Out:
# 0
# 1
# 1
# 0

# %%
# %cd /content/drive/MyDrive/DCLab_study/DeepLearning_from_Scratch

# # 'your_token_here' 부분에 방금 복사한 토큰을 붙여넣으세요.
# TOKEN = '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'
USERNAME = 'yangjaehoon'
REPO = 'DCLab_study'

# # 토큰을 포함한 URL로 remote 주소를 업데이트합니다.
# !git remote set-url origin https://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@github.com/yangjaehoon/DCLab_study.git
# !git add 2_perceptron.ipynb
# !git commit -m '2장 퍼셉트론.'
# # 이제 다시 push를 시도해보세요.
# !git push
# Out:
# /content/drive/MyDrive/DCLab_study/DeepLearning_from_Scratch
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@a143b2252605.(none)')
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 1.70 KiB | 75.00 KiB/s, done.
# Total 8 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 1 local object.
# remote: error: GH013: Repository rule violations found for refs/heads/main.
# remote:
# remote: - GITHUB PUSH PROTECTION
# remote:   —————————————————————————————————————————
# ...
