# %% [markdown]
# # 2.3 퍼셉트론 구현하기

# %% [markdown]
# 2.3.1 간단한 구현

# %%
def AND(x1, x2):
  w1, w2, theta = 0.5, 0.5, 0.7
  tmp = x1*w1 + x2*w2
  if tmp <= theta:
    return 0
  elif tmp > theta:
    return 1

# %%
print(AND(0, 0))
print(AND(1, 0))
print(AND(0, 1))
print(AND(1, 1))
# Out:
# 0
# 0
# 0
# 1

# %% [markdown]
# 2.3.2 가중치와 편향 도입

# %%
import numpy as np
x = np.array([0, 1])
w = np.array([0.5, 0.5])
b = -0.7

# %%
w*x
# Out:
# array([0. , 0.5])

# %%
np.sum(w*x)
# Out:
# np.float64(0.5)

# %%
np.sum(w*x) + b
# Out:
# np.float64(-0.19999999999999996)

# %% [markdown]
# 2.3.3 가중치와 편향 구현하기

# %%
def AND(x1, x2):
  x = np.array([x1, x2])
  w = np.array([0.5, 0.5])
  b = -0.7
  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else:
    return 1

# %%
def NAND(x1, x2):
  x = np.array([x1, x2])
  w = np.array([-0.5, -0.5])
  b = 0.7
  tmp = np.sum(w*x) +b
  if tmp <= 0:
    return 0
  else:
    return 1

# %%
def OR(x1, x2):
  x = np.array([x1, x2])
  w = np.array([0.5, 0.5])
  b = -0.2
  tmp = np.sum(w*x) + b
  if tmp <= 0:
    return 0
  else:
    return 1

# %% [markdown]
# 2.5.2 XOR 게이트 구현하기

# %%
def XOR(x1, x2):
  s1 = NAND(x1, x2)
  s2 = OR(x1, x2)
  y = AND(s1, s2)
  return y

# %%
print(XOR(0,0))
print(XOR(1,0))
print(XOR(0,1))
print(XOR(1,1))
# Out:
# 0
# 1
# 1
# 0

# %%
from google.colab import userdata
import os

# %cd /content/drive/MyDrive/DCLab_study/DeepLearning_from_Scratch

TOKEN = userdata.get('GH_TOKEN')
USERNAME = 'yangjaehoon'
REPO = 'DCLab_study'

# !git config --global user.email "lljhms@naver.com"
# !git config --global user.name "yangjaehoon"


# !git remote set-url origin https://{TOKEN}@github.com/{USERNAME}/{REPO}.git
# !git add 2_perceptron.ipynb
# !git commit -m '2장 퍼셉트론.'
# !git push
# Out:
# /content/drive/MyDrive/DCLab_study/DeepLearning_from_Scratch
# [main dcf75df] 2장 퍼셉트론.
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 650 bytes | 65.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/yangjaehoon/DCLab_study.git
#    feea6e4..dcf75df  main -> main
